# %%
! pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.25.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.64.1)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.43.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.0.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2024.6.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow) (2.1.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (3.2.2)

# %%
# !gdown --id 1qm0Ty5onZX3H1Our7TvaCFOCvNu3wvyw
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/__main__.py:132: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1qm0Ty5onZX3H1Our7TvaCFOCvNu3wvyw
# To: /content/captcha_images_v2.zip
# 100% 9.08M/9.08M [00:00<00:00, 16.9MB/s]

# %%
# !unzip captcha_images_v2.zip
# Out:
# Archive:  captcha_images_v2.zip
#    creating: captcha_images_v2/
#  extracting: captcha_images_v2/ydd3g.png
#  extracting: captcha_images_v2/36nx4.png
#  extracting: captcha_images_v2/3bnyf.png
#  extracting: captcha_images_v2/8y6b3.png
#  extracting: captcha_images_v2/268g2.png
#  extracting: captcha_images_v2/mnef5.png
#  extracting: captcha_images_v2/5p8fm.png
#  extracting: captcha_images_v2/bxxfc.png
#  extracting: captcha_images_v2/8ypdn.png
#  extracting: captcha_images_v2/gpxng.png
#  extracting: captcha_images_v2/e4gd7.png
#  extracting: captcha_images_v2/pbpgc.png
#  extracting: captcha_images_v2/m4g8g.png
#   inflating: captcha_images_v2/c43b4.png
#  extracting: captcha_images_v2/gwnm6.png
#  extracting: captcha_images_v2/w4x2m.png
#  extracting: captcha_images_v2/npxb7.png
#  extracting: captcha_images_v2/445cc.png
#  extracting: captcha_images_v2/pg2pm.png
#  extracting: captcha_images_v2/wc2bd.png
#  extracting: captcha_images_v2/mc8w2.png
#  extracting: captcha_images_v2/678w3.png
#   inflating: captcha_images_v2/gny6b.png
#   inflating: captcha_images_v2/47m2b.png
#  extracting: captcha_images_v2/7cgym.png
#  extracting: captcha_images_v2/ccf2w.png
#   inflating: captcha_images_v2/px8n8.png
#  extracting: captcha_images_v2/y7d75.png
#   inflating: captcha_images_v2/b2g8e.png
#  extracting: captcha_images_v2/yd755.png
#  extracting: captcha_images_v2/yd38e.png
#  extracting: captcha_images_v2/yxd7m.png
#  extracting: captcha_images_v2/5xd2e.png
#  extracting: captcha_images_v2/gegw4.png
#   inflating: captcha_images_v2/g55b4.png
#  extracting: captcha_images_v2/537nf.png
#  extracting: captcha_images_v2/xe6eb.png
#  extracting: captcha_images_v2/ndme7.png
#  extracting: captcha_images_v2/wdww8.png
#  extracting: captcha_images_v2/36bc2.png
#  extracting: captcha_images_v2/m22e3.png
#  extracting: captcha_images_v2/76y6f.png
#  extracting: captcha_images_v2/63pxe.png
#  extracting: captcha_images_v2/xnd3y.png
#  extracting: captcha_images_v2/p6mn8.png
#  extracting: captcha_images_v2/3xcgg.png
#  extracting: captcha_images_v2/p2m6n.png
#  extracting: captcha_images_v2/gcfgp.png
#  extracting: captcha_images_v2/xdcn4.png
#  extracting: captcha_images_v2/4f8yp.png
#  extracting: captcha_images_v2/cwgyx.png
#  extracting: captcha_images_v2/ywn6f.png
#   inflating: captcha_images_v2/yx2d4.png
#  extracting: captcha_images_v2/662bw.png
#  extracting: captcha_images_v2/y32yy.png
#  extracting: captcha_images_v2/pgg3n.png
#  extracting: captcha_images_v2/2wc38.png
#  extracting: captcha_images_v2/n6f4b.png
#  extracting: captcha_images_v2/wye85.png
#  extracting: captcha_images_v2/226md.png
#  extracting: captcha_images_v2/xemyg.png
#  extracting: captcha_images_v2/mgdwb.png
#   inflating: captcha_images_v2/33b22.png
#   inflating: captcha_images_v2/f228n.png
#  extracting: captcha_images_v2/8d4wm.png
#  extracting: captcha_images_v2/2mg87.png
#  extracting: captcha_images_v2/eng53.png
#  extracting: captcha_images_v2/pmf5w.png
#  extracting: captcha_images_v2/c6we6.png
#   inflating: captcha_images_v2/6bnnm.png
#   inflating: captcha_images_v2/n7dyb.png
#  extracting: captcha_images_v2/m8m4x.png
#  extracting: captcha_images_v2/fyfbn.png
#  extracting: captcha_images_v2/bm3p8.png
#  extracting: captcha_images_v2/7bwm2.png
#   inflating: captcha_images_v2/neggn.png
#  extracting: captcha_images_v2/mpmy5.png
#  extracting: captcha_images_v2/bdg84.png
#  extracting: captcha_images_v2/pg2yx.png
#  extracting: captcha_images_v2/nxxf8.png
#  extracting: captcha_images_v2/7b4bm.png
#  extracting: captcha_images_v2/x3fwf.png
#  extracting: captcha_images_v2/xyncc.png
#  extracting: captcha_images_v2/2fxgd.png
#  extracting: captcha_images_v2/3n3cf.png
#  extracting: captcha_images_v2/w7e6m.png
#   inflating: captcha_images_v2/mye68.png
#   inflating: captcha_images_v2/cfc56.png
#  extracting: captcha_images_v2/387g2.png
#  extracting: captcha_images_v2/xf5g7.png
#  extracting: captcha_images_v2/2pfpn.png
#  extracting: captcha_images_v2/25p2m.png
#  extracting: captcha_images_v2/m3wfw.png
#  extracting: captcha_images_v2/2nbcx.png
#  extracting: captcha_images_v2/28348.png
#  extracting: captcha_images_v2/c2yn8.png
#  extracting: captcha_images_v2/5nxnn.png
#  extracting: captcha_images_v2/ddpyb.png
#  extracting: captcha_images_v2/c353e.png
#  extracting: captcha_images_v2/x4pnp.png
#  extracting: captcha_images_v2/bp2d4.png
#  extracting: captcha_images_v2/fcey3.png
#  extracting: captcha_images_v2/25m6p.png
#  extracting: captcha_images_v2/e8e5e.png
#  extracting: captcha_images_v2/34fxm.png
#   inflating: captcha_images_v2/3x325.png
#  extracting: captcha_images_v2/2g783.png
#  extracting: captcha_images_v2/ppx77.png
#   inflating: captcha_images_v2/ccn2x.png
#  extracting: captcha_images_v2/5g5e5.png
#   inflating: captcha_images_v2/xxney.png
#  extracting: captcha_images_v2/pw5nc.png
#  extracting: captcha_images_v2/pnnwy.png
#  extracting: captcha_images_v2/cnmnn.png
#  extracting: captcha_images_v2/2x7bm.png
#   inflating: captcha_images_v2/g7gnf.png
#   inflating: captcha_images_v2/ecd4w.png
#  extracting: captcha_images_v2/p8ngx.png
#  extracting: captcha_images_v2/6cm6m.png
#  extracting: captcha_images_v2/4b2pw.png
#  extracting: captcha_images_v2/wbncw.png
#   inflating: captcha_images_v2/e5n66.png
#  extracting: captcha_images_v2/76353.png
#  extracting: captcha_images_v2/n3x4c.png
#  extracting: captcha_images_v2/488de.png
#  extracting: captcha_images_v2/ngn26.png
#  extracting: captcha_images_v2/x458w.png
#  extracting: captcha_images_v2/5n732.png
#  extracting: captcha_images_v2/fp5wn.png
#  extracting: captcha_images_v2/ydg8n.png
#   inflating: captcha_images_v2/gymmn.png
#  extracting: captcha_images_v2/d3c7y.png
#  extracting: captcha_images_v2/m2nf4.png
#   inflating: captcha_images_v2/d378n.png
#   inflating: captcha_images_v2/p4pde.png
#   inflating: captcha_images_v2/244e2.png
#  extracting: captcha_images_v2/mbf58.png
#   inflating: captcha_images_v2/664nf.png
#  extracting: captcha_images_v2/bwmee.png
#  extracting: captcha_images_v2/en4n4.png
#  extracting: captcha_images_v2/m448b.png
#  extracting: captcha_images_v2/fbp2c.png
#   inflating: captcha_images_v2/7d44m.png
#  extracting: captcha_images_v2/6bxwg.png
#   inflating: captcha_images_v2/43p5d.png
#  extracting: captcha_images_v2/yf424.png
#  extracting: captcha_images_v2/58b5m.png
#   inflating: captcha_images_v2/wf684.png
#  extracting: captcha_images_v2/36w25.png
#  extracting: captcha_images_v2/y4ec2.png
#  extracting: captcha_images_v2/728n8.png
#  extracting: captcha_images_v2/pn7pn.png
#  extracting: captcha_images_v2/m74dm.png
#  extracting: captcha_images_v2/ncw4g.png
#  extracting: captcha_images_v2/xnnc3.png
#  extracting: captcha_images_v2/ewnx8.png
#  extracting: captcha_images_v2/3ebnn.png
#  extracting: captcha_images_v2/x4f7g.png
#  extracting: captcha_images_v2/5mcy7.png
#  extracting: captcha_images_v2/gnf85.png
#  extracting: captcha_images_v2/f35xp.png
#  extracting: captcha_images_v2/8n2pg.png
#  extracting: captcha_images_v2/64b3p.png
#  extracting: captcha_images_v2/43xfe.png
#  extracting: captcha_images_v2/5n3w4.png
#   inflating: captcha_images_v2/yf28d.png
#  extracting: captcha_images_v2/y4n6m.png
#  extracting: captcha_images_v2/368y5.png
#  extracting: captcha_images_v2/m5ym2.png
#  extracting: captcha_images_v2/7yf62.png
#  extracting: captcha_images_v2/b5dn4.png
#  extracting: captcha_images_v2/bcwnn.png
#   inflating: captcha_images_v2/ycnfc.png
#  extracting: captcha_images_v2/3bfnd.png
#  extracting: captcha_images_v2/5expp.png
#  extracting: captcha_images_v2/55y2m.png
#  extracting: captcha_images_v2/dcnp8.png
#  extracting: captcha_images_v2/6xen4.png
#  extracting: captcha_images_v2/d6fcn.png
#  extracting: captcha_images_v2/wyc25.png
#   inflating: captcha_images_v2/x44n4.png
#   inflating: captcha_images_v2/dyxnc.png
#   inflating: captcha_images_v2/84w7x.png
#  extracting: captcha_images_v2/33f7m.png
#  extracting: captcha_images_v2/fwxdp.png
#  extracting: captcha_images_v2/5xwcg.png
#  extracting: captcha_images_v2/ef4mn.png
#  extracting: captcha_images_v2/43gey.png
#  extracting: captcha_images_v2/7dxbd.png
#  extracting: captcha_images_v2/nn6mg.png
#  extracting: captcha_images_v2/wm47f.png
#  extracting: captcha_images_v2/dc436.png
#  extracting: captcha_images_v2/nn4wx.png
#   inflating: captcha_images_v2/n5wbg.png
#  extracting: captcha_images_v2/gn2xy.png
#  extracting: captcha_images_v2/cewnm.png
#  extracting: captcha_images_v2/yyn57.png
#  extracting: captcha_images_v2/y3c58.png
#  extracting: captcha_images_v2/34pcn.png
#  extracting: captcha_images_v2/8bbw8.png
#   inflating: captcha_images_v2/wddcp.png
#   inflating: captcha_images_v2/mcc2x.png
#  extracting: captcha_images_v2/m4fd8.png
#  extracting: captcha_images_v2/2yggg.png
#  extracting: captcha_images_v2/ef4np.png
#  extracting: captcha_images_v2/nnp4e.png
#   inflating: captcha_images_v2/dw6mn.png
#  extracting: captcha_images_v2/w2n7e.png
#  extracting: captcha_images_v2/y5dpp.png
#   inflating: captcha_images_v2/c6745.png
#   inflating: captcha_images_v2/6fg8c.png
#   inflating: captcha_images_v2/gf2g4.png
#  extracting: captcha_images_v2/87d4c.png
#  extracting: captcha_images_v2/dmx8p.png
#  extracting: captcha_images_v2/8wy7d.png
#   inflating: captcha_images_v2/en32e.png
#  extracting: captcha_images_v2/e84n2.png
#  extracting: captcha_images_v2/37d52.png
#   inflating: captcha_images_v2/bgem5.png
#  extracting: captcha_images_v2/w2yp7.png
#  extracting: captcha_images_v2/gdng3.png
#  extracting: captcha_images_v2/nybcx.png
#  extracting: captcha_images_v2/n3m6x.png
#   inflating: captcha_images_v2/55w5c.png
#  extracting: captcha_images_v2/byfgn.png
#  extracting: captcha_images_v2/7634y.png
#  extracting: captcha_images_v2/5fyem.png
#   inflating: captcha_images_v2/gcx6f.png
#  extracting: captcha_images_v2/emwpn.png
#  extracting: captcha_images_v2/wwmn6.png
#  extracting: captcha_images_v2/3bx86.png
#  extracting: captcha_images_v2/nbp3e.png
#   inflating: captcha_images_v2/gy433.png
#  extracting: captcha_images_v2/p2dw7.png
#  extracting: captcha_images_v2/yfdn7.png
#   inflating: captcha_images_v2/fcne6.png
#  extracting: captcha_images_v2/57gnx.png
#  extracting: captcha_images_v2/32dnn.png
#  extracting: captcha_images_v2/nm248.png
#  extracting: captcha_images_v2/xw465.png
#  extracting: captcha_images_v2/pxne8.png
#  extracting: captcha_images_v2/xdn65.png
#  extracting: captcha_images_v2/ennmm.png
#  extracting: captcha_images_v2/pdyc8.png
#   inflating: captcha_images_v2/3mxdn.png
#   inflating: captcha_images_v2/2b827.png
#   inflating: captcha_images_v2/d2ycw.png
#  extracting: captcha_images_v2/m457d.png
#  extracting: captcha_images_v2/22d5n.png
#  extracting: captcha_images_v2/ypp8f.png
#  extracting: captcha_images_v2/nfbg8.png
#  extracting: captcha_images_v2/8cm46.png
#  extracting: captcha_images_v2/865wm.png
#   inflating: captcha_images_v2/n8fp6.png
#  extracting: captcha_images_v2/8n5pn.png
#  extracting: captcha_images_v2/gd8fb.png
#  extracting: captcha_images_v2/57b27.png
#  extracting: captcha_images_v2/g7wxw.png
#   inflating: captcha_images_v2/x7547.png
#  extracting: captcha_images_v2/4433m.png
#   inflating: captcha_images_v2/w4cnn.png
#  extracting: captcha_images_v2/7nnnx.png
#  extracting: captcha_images_v2/ybfx6.png
#  extracting: captcha_images_v2/myc3c.png
#  extracting: captcha_images_v2/p5nce.png
#  extracting: captcha_images_v2/x362g.png
#  extracting: captcha_images_v2/w2e87.png
#  extracting: captcha_images_v2/dd764.png
#   inflating: captcha_images_v2/2nf26.png
#  extracting: captcha_images_v2/mpxfb.png
#  extracting: captcha_images_v2/x4gg5.png
#  extracting: captcha_images_v2/ffnxn.png
#  extracting: captcha_images_v2/5dxnm.png
#   inflating: captcha_images_v2/n7ebx.png
#   inflating: captcha_images_v2/56ncx.png
#  extracting: captcha_images_v2/6e2dg.png
#   inflating: captcha_images_v2/56c34.png
#  extracting: captcha_images_v2/mm3nn.png
#  extracting: captcha_images_v2/6xxdx.png
#  extracting: captcha_images_v2/wm746.png
#  extracting: captcha_images_v2/56m6y.png
#  extracting: captcha_images_v2/yy824.png
#  extracting: captcha_images_v2/xc68n.png
#  extracting: captcha_images_v2/428b6.png
#   inflating: captcha_images_v2/dmw8n.png
#   inflating: captcha_images_v2/nbcgb.png
#  extracting: captcha_images_v2/fc2ff.png
#  extracting: captcha_images_v2/4nc37.png
#  extracting: captcha_images_v2/ng756.png
#  extracting: captcha_images_v2/3p4nn.png
#  extracting: captcha_images_v2/68wfd.png
#   inflating: captcha_images_v2/m67b3.png
#  extracting: captcha_images_v2/wfy5m.png
#  extracting: captcha_images_v2/d236n.png
#  extracting: captcha_images_v2/f83pn.png
#  extracting: captcha_images_v2/8gmc4.png
#   inflating: captcha_images_v2/3ny45.png
#  extracting: captcha_images_v2/wgnwp.png
#  extracting: captcha_images_v2/c4mcm.png
#   inflating: captcha_images_v2/64m82.png
#  extracting: captcha_images_v2/b43nw.png
#  extracting: captcha_images_v2/b4y5x.png
#  extracting: captcha_images_v2/b4d7c.png
#  extracting: captcha_images_v2/6p7gx.png
#  extracting: captcha_images_v2/7m8px.png
#  extracting: captcha_images_v2/e72cd.png
#  extracting: captcha_images_v2/yw667.png
#  extracting: captcha_images_v2/x8e8n.png
#  extracting: captcha_images_v2/b35f6.png
#  extracting: captcha_images_v2/xp24p.png
#  extracting: captcha_images_v2/832f3.png
#  extracting: captcha_images_v2/65m85.png
#  extracting: captcha_images_v2/264m5.png
#  extracting: captcha_images_v2/xnn4d.png
#  extracting: captcha_images_v2/f4wfn.png
#  extracting: captcha_images_v2/d22bd.png
#  extracting: captcha_images_v2/pgm2e.png
#  extracting: captcha_images_v2/pnmxf.png
#  extracting: captcha_images_v2/pcede.png
#  extracting: captcha_images_v2/7y2x4.png
#  extracting: captcha_images_v2/g7fmc.png
#  extracting: captcha_images_v2/n4b4m.png
#  extracting: captcha_images_v2/7p852.png
#   inflating: captcha_images_v2/5npdn.png
#  extracting: captcha_images_v2/4w6mw.png
#  extracting: captcha_images_v2/3ebpw.png
#  extracting: captcha_images_v2/p5g5m.png
#  extracting: captcha_images_v2/cffp4.png
#  extracting: captcha_images_v2/8np22.png
#  extracting: captcha_images_v2/2cegf.png
#  extracting: captcha_images_v2/n464c.png
#  extracting: captcha_images_v2/gp22x.png
#  extracting: captcha_images_v2/3den6.png
#  extracting: captcha_images_v2/33n73.png
#   inflating: captcha_images_v2/f85y3.png
#   inflating: captcha_images_v2/646x8.png
#  extracting: captcha_images_v2/md344.png
#  extracting: captcha_images_v2/cm6yb.png
#  extracting: captcha_images_v2/ng46m.png
#  extracting: captcha_images_v2/gng6e.png
#  extracting: captcha_images_v2/87nym.png
#  extracting: captcha_images_v2/5f3gf.png
#  extracting: captcha_images_v2/mn5c4.png
#  extracting: captcha_images_v2/4cfw8.png
#  extracting: captcha_images_v2/wg625.png
#  extracting: captcha_images_v2/n265y.png
#  extracting: captcha_images_v2/y5n6d.png
#   inflating: captcha_images_v2/gnc3n.png
#  extracting: captcha_images_v2/fywb8.png
#  extracting: captcha_images_v2/x5f54.png
#  extracting: captcha_images_v2/3p67n.png
#  extracting: captcha_images_v2/g2fnw.png
#   inflating: captcha_images_v2/exycn.png
#   inflating: captcha_images_v2/3cpwb.png
#  extracting: captcha_images_v2/xcf88.png
#  extracting: captcha_images_v2/f4fn2.png
#  extracting: captcha_images_v2/nf7bn.png
#  extracting: captcha_images_v2/6pfy4.png
#  extracting: captcha_images_v2/ggd7m.png
#  extracting: captcha_images_v2/yemy4.png
#  extracting: captcha_images_v2/nbfx5.png
#  extracting: captcha_images_v2/f2m8n.png
#   inflating: captcha_images_v2/6f857.png
#  extracting: captcha_images_v2/cfw6e.png
#  extracting: captcha_images_v2/6wnyc.png
#   inflating: captcha_images_v2/2cg58.png
#  extracting: captcha_images_v2/3wnd3.png
#  extracting: captcha_images_v2/m23bp.png
#   inflating: captcha_images_v2/785n4.png
#  extracting: captcha_images_v2/8g4yp.png
#   inflating: captcha_images_v2/e8dxn.png
#  extracting: captcha_images_v2/6fn84.png
#  extracting: captcha_images_v2/4dw3w.png
#  extracting: captcha_images_v2/c55c6.png
#  extracting: captcha_images_v2/c3n8x.png
#   inflating: captcha_images_v2/5n728.png
#   inflating: captcha_images_v2/bnc2f.png
#  extracting: captcha_images_v2/edg3p.png
#   inflating: captcha_images_v2/573d8.png
#  extracting: captcha_images_v2/ypw3d.png
#  extracting: captcha_images_v2/xfgxb.png
#  extracting: captcha_images_v2/ndg2b.png
#   inflating: captcha_images_v2/m8gmx.png
#  extracting: captcha_images_v2/ncww7.png
#  extracting: captcha_images_v2/b26nd.png
#  extracting: captcha_images_v2/neecd.png
#   inflating: captcha_images_v2/nnf8b.png
#  extracting: captcha_images_v2/nfg23.png
#  extracting: captcha_images_v2/enn7n.png
#  extracting: captcha_images_v2/c2pg6.png
#   inflating: captcha_images_v2/573bn.png
#  extracting: captcha_images_v2/pwebm.png
#  extracting: captcha_images_v2/c8fxy.png
#  extracting: captcha_images_v2/8n5p3.png
#  extracting: captcha_images_v2/23n88.png
#  extracting: captcha_images_v2/yg5bb.png
#  extracting: captcha_images_v2/67dey.png
#  extracting: captcha_images_v2/7gp47.png
#  extracting: captcha_images_v2/f75cx.png
#   inflating: captcha_images_v2/myf82.png
#  extracting: captcha_images_v2/7wyp4.png
#   inflating: captcha_images_v2/nwg2m.png
#  extracting: captcha_images_v2/77wp4.png
#  extracting: captcha_images_v2/fdpgd.png
#  extracting: captcha_images_v2/8n34n.png
#   inflating: captcha_images_v2/cdcb3.png
#  extracting: captcha_images_v2/8nbew.png
#  extracting: captcha_images_v2/6ng6n.png
#  extracting: captcha_images_v2/33ng4.png
#  extracting: captcha_images_v2/fw3b2.png
#  extracting: captcha_images_v2/mfc35.png
#  extracting: captcha_images_v2/cd6p4.png
#  extracting: captcha_images_v2/5gcd3.png
#  extracting: captcha_images_v2/ncyx8.png
#  extracting: captcha_images_v2/3pe4g.png
#  extracting: captcha_images_v2/6c3n6.png
#   inflating: captcha_images_v2/4cn7b.png
#   inflating: captcha_images_v2/7pcd7.png
#  extracting: captcha_images_v2/n5cm7.png
#  extracting: captcha_images_v2/e2mg2.png
#  extracting: captcha_images_v2/78eec.png
#  extracting: captcha_images_v2/deneb.png
#  extracting: captcha_images_v2/w6pxy.png
#   inflating: captcha_images_v2/cpe63.png
#  extracting: captcha_images_v2/p24gn.png
#   inflating: captcha_images_v2/4fc36.png
#   inflating: captcha_images_v2/d7c5x.png
#  extracting: captcha_images_v2/cen55.png
#  extracting: captcha_images_v2/7w67m.png
#  extracting: captcha_images_v2/ffd6p.png
#  extracting: captcha_images_v2/n336e.png
#  extracting: captcha_images_v2/8bbm4.png
#  extracting: captcha_images_v2/66wp5.png
#  extracting: captcha_images_v2/xymfn.png
#  extracting: captcha_images_v2/mcyfx.png
#  extracting: captcha_images_v2/7dgc2.png
#  extracting: captcha_images_v2/bnc5f.png
#  extracting: captcha_images_v2/6dmx7.png
#  extracting: captcha_images_v2/nmy2x.png
#  extracting: captcha_images_v2/cfp86.png
#  extracting: captcha_images_v2/g3dy6.png
#   inflating: captcha_images_v2/53wp3.png
#  extracting: captcha_images_v2/y5w28.png
#  extracting: captcha_images_v2/dn5df.png
#  extracting: captcha_images_v2/2mpnn.png
#  extracting: captcha_images_v2/pp87n.png
#  extracting: captcha_images_v2/nmw46.png
#  extracting: captcha_images_v2/4ycex.png
#   inflating: captcha_images_v2/ycmcw.png
#  extracting: captcha_images_v2/6wg4n.png
#  extracting: captcha_images_v2/ny8np.png
#  extracting: captcha_images_v2/6n443.png
#   inflating: captcha_images_v2/wxcn8.png
#   inflating: captcha_images_v2/y7mnm.png
#   inflating: captcha_images_v2/efe62.png
#  extracting: captcha_images_v2/6825y.png
#  extracting: captcha_images_v2/cwmny.png
#   inflating: captcha_images_v2/f364x.png
#  extracting: captcha_images_v2/6ge3p.png
#  extracting: captcha_images_v2/e3ndn.png
#  extracting: captcha_images_v2/24pew.png
#  extracting: captcha_images_v2/7mgmf.png
#  extracting: captcha_images_v2/6mege.png
#  extracting: captcha_images_v2/7wn74.png
#  extracting: captcha_images_v2/w4nfx.png
#   inflating: captcha_images_v2/efb3f.png
#  extracting: captcha_images_v2/44fyb.png
#  extracting: captcha_images_v2/ppwyd.png
#  extracting: captcha_images_v2/e46pd.png
#  extracting: captcha_images_v2/f753f.png
#  extracting: captcha_images_v2/ng6yp.png
#  extracting: captcha_images_v2/3nnpw.png
#  extracting: captcha_images_v2/ygenn.png
#  extracting: captcha_images_v2/xgcxy.png
#  extracting: captcha_images_v2/8gmnx.png
#  extracting: captcha_images_v2/bgb48.png
#   inflating: captcha_images_v2/mgw3n.png
#  extracting: captcha_images_v2/4egem.png
#  extracting: captcha_images_v2/ndecc.png
#  extracting: captcha_images_v2/474ff.png
#   inflating: captcha_images_v2/mmg38.png
#  extracting: captcha_images_v2/8n65n.png
#  extracting: captcha_images_v2/p4nm4.png
#   inflating: captcha_images_v2/cwdnx.png
#  extracting: captcha_images_v2/pme86.png
#  extracting: captcha_images_v2/y2ye8.png
#  extracting: captcha_images_v2/nfcwy.png
#  extracting: captcha_images_v2/76nxn.png
#  extracting: captcha_images_v2/8c2wy.png
#  extracting: captcha_images_v2/42nxy.png
#   inflating: captcha_images_v2/6c3p5.png
#  extracting: captcha_images_v2/px2xp.png
#  extracting: captcha_images_v2/7bb7b.png
#   inflating: captcha_images_v2/w6yne.png
#  extracting: captcha_images_v2/mdxpn.png
#   inflating: captcha_images_v2/74853.png
#  extracting: captcha_images_v2/dw8d3.png
#  extracting: captcha_images_v2/f6ne5.png
#  extracting: captcha_images_v2/dy3cx.png
#  extracting: captcha_images_v2/gm6nn.png
#  extracting: captcha_images_v2/bw5nf.png
#   inflating: captcha_images_v2/p8c24.png
#  extracting: captcha_images_v2/y33nm.png
#  extracting: captcha_images_v2/n3bm6.png
#  extracting: captcha_images_v2/65ebm.png
#   inflating: captcha_images_v2/w8bnx.png
#  extracting: captcha_images_v2/c3572.png
#  extracting: captcha_images_v2/3d7bd.png
#  extracting: captcha_images_v2/3eny7.png
#  extracting: captcha_images_v2/men4f.png
#  extracting: captcha_images_v2/wmpmp.png
#  extracting: captcha_images_v2/pyefb.png
#  extracting: captcha_images_v2/5n245.png
#  extracting: captcha_images_v2/x74b2.png
#  extracting: captcha_images_v2/xe8xm.png
#  extracting: captcha_images_v2/pxdwp.png
#  extracting: captcha_images_v2/63824.png
#  extracting: captcha_images_v2/58pnp.png
#   inflating: captcha_images_v2/373gb.png
#  extracting: captcha_images_v2/4c8n8.png
#  extracting: captcha_images_v2/ymp7g.png
#  extracting: captcha_images_v2/7dwx4.png
#  extracting: captcha_images_v2/bbymy.png
#  extracting: captcha_images_v2/f7cey.png
#  extracting: captcha_images_v2/8npe3.png
#  extracting: captcha_images_v2/wxy4n.png
#   inflating: captcha_images_v2/be6np.png
#  extracting: captcha_images_v2/478nx.png
#  extracting: captcha_images_v2/nw5b2.png
#  extracting: captcha_images_v2/cdf77.png
#  extracting: captcha_images_v2/mx8bb.png
#   inflating: captcha_images_v2/bn5mw.png
#  extracting: captcha_images_v2/bw6n6.png
#  extracting: captcha_images_v2/bc8nf.png
#  extracting: captcha_images_v2/mmfm6.png
#   inflating: captcha_images_v2/e6b7y.png
#  extracting: captcha_images_v2/75pfw.png
#  extracting: captcha_images_v2/2g7nm.png
#   inflating: captcha_images_v2/x5nyn.png
#   inflating: captcha_images_v2/f8f8g.png
#  extracting: captcha_images_v2/44ype.png
#  extracting: captcha_images_v2/g842c.png
#  extracting: captcha_images_v2/88bgx.png
#   inflating: captcha_images_v2/c7nn8.png
#  extracting: captcha_images_v2/25egp.png
#   inflating: captcha_images_v2/3bd8f.png
#  extracting: captcha_images_v2/dxwcw.png
#  extracting: captcha_images_v2/42dw4.png
#   inflating: captcha_images_v2/nxcmn.png
#  extracting: captcha_images_v2/8e32m.png
#  extracting: captcha_images_v2/7gce6.png
#   inflating: captcha_images_v2/gnbn4.png
#  extracting: captcha_images_v2/deep5.png
#  extracting: captcha_images_v2/x76mn.png
#   inflating: captcha_images_v2/664dn.png
#  extracting: captcha_images_v2/xwx7d.png
#   inflating: captcha_images_v2/nwfde.png
#   inflating: captcha_images_v2/dd5w5.png
#  extracting: captcha_images_v2/5ng6e.png
#   inflating: captcha_images_v2/ec6pm.png
#  extracting: captcha_images_v2/my84e.png
#   inflating: captcha_images_v2/bny23.png
#  extracting: captcha_images_v2/c7gb3.png
#  extracting: captcha_images_v2/3nfdn.png
#  extracting: captcha_images_v2/dbpcd.png
#  extracting: captcha_images_v2/wce5n.png
#   inflating: captcha_images_v2/nf2n8.png
#  extracting: captcha_images_v2/cc845.png
#  extracting: captcha_images_v2/cpc8c.png
#  extracting: captcha_images_v2/n6nn2.png
#  extracting: captcha_images_v2/6mygb.png
#  extracting: captcha_images_v2/25257.png
#  extracting: captcha_images_v2/p57fn.png
#  extracting: captcha_images_v2/n2gmg.png
#  extracting: captcha_images_v2/wecfd.png
#  extracting: captcha_images_v2/8n62n.png
#  extracting: captcha_images_v2/85622.png
#  extracting: captcha_images_v2/6pwcn.png
#  extracting: captcha_images_v2/8cccc.png
#  extracting: captcha_images_v2/574d7.png
#  extracting: captcha_images_v2/f74x3.png
#   inflating: captcha_images_v2/mddgb.png
#  extracting: captcha_images_v2/yeyn4.png
#   inflating: captcha_images_v2/bdbb3.png
#  extracting: captcha_images_v2/gm7n8.png
#  extracting: captcha_images_v2/pwmbn.png
#  extracting: captcha_images_v2/2p2y8.png
#  extracting: captcha_images_v2/5bgp2.png
#   inflating: captcha_images_v2/mp7wp.png
#  extracting: captcha_images_v2/d7nn3.png
#  extracting: captcha_images_v2/mmc5n.png
#  extracting: captcha_images_v2/nnn57.png
#   inflating: captcha_images_v2/d3c8y.png
#  extracting: captcha_images_v2/7cdge.png
#  extracting: captcha_images_v2/dbny3.png
#   inflating: captcha_images_v2/g888x.png
#  extracting: captcha_images_v2/cg5dd.png
#  extracting: captcha_images_v2/4fp5g.png
#  extracting: captcha_images_v2/y7x8p.png
#  extracting: captcha_images_v2/8npd5.png
#  extracting: captcha_images_v2/658xe.png
#  extracting: captcha_images_v2/mggce.png
#  extracting: captcha_images_v2/de7f8.png
#  extracting: captcha_images_v2/2enf4.png
#   inflating: captcha_images_v2/fg38b.png
#  extracting: captcha_images_v2/b6f2p.png
#  extracting: captcha_images_v2/x6b5m.png
#   inflating: captcha_images_v2/ddnpf.png
#  extracting: captcha_images_v2/g247w.png
#  extracting: captcha_images_v2/nnfx3.png
#  extracting: captcha_images_v2/3nw7w.png
#  extracting: captcha_images_v2/xbem6.png
#  extracting: captcha_images_v2/n3ffn.png
#  extracting: captcha_images_v2/n5n8b.png
#  extracting: captcha_images_v2/6e6pn.png
#  extracting: captcha_images_v2/68x48.png
#   inflating: captcha_images_v2/253dc.png
#  extracting: captcha_images_v2/mmy5n.png
#  extracting: captcha_images_v2/de45x.png
#  extracting: captcha_images_v2/y2436.png
#  extracting: captcha_images_v2/xf4p4.png
#  extracting: captcha_images_v2/4w76g.png
#  extracting: captcha_images_v2/cd4eg.png
#  extracting: captcha_images_v2/c4bgd.png
#  extracting: captcha_images_v2/yf347.png
#   inflating: captcha_images_v2/fp762.png
#  extracting: captcha_images_v2/2356g.png
#  extracting: captcha_images_v2/33p4e.png
#   inflating: captcha_images_v2/ng2gw.png
#  extracting: captcha_images_v2/mw5p2.png
#  extracting: captcha_images_v2/edwny.png
#  extracting: captcha_images_v2/y866y.png
#   inflating: captcha_images_v2/5x5nx.png
#   inflating: captcha_images_v2/7gmf3.png
#  extracting: captcha_images_v2/f5e5e.png
#   inflating: captcha_images_v2/ne325.png
#  extracting: captcha_images_v2/7wnpm.png
#  extracting: captcha_images_v2/24f6w.png
#  extracting: captcha_images_v2/mfb3x.png
#   inflating: captcha_images_v2/ncfgb.png
#   inflating: captcha_images_v2/82fx2.png
#  extracting: captcha_images_v2/pyf65.png
#   inflating: captcha_images_v2/467d5.png
#  extracting: captcha_images_v2/y5g87.png
#  extracting: captcha_images_v2/pdw38.png
#   inflating: captcha_images_v2/53mn8.png
#   inflating: captcha_images_v2/n6xc5.png
#  extracting: captcha_images_v2/6g45w.png
#  extracting: captcha_images_v2/6cwxe.png
#  extracting: captcha_images_v2/77n6g.png
#  extracting: captcha_images_v2/e43ym.png
#  extracting: captcha_images_v2/w52fn.png
#  extracting: captcha_images_v2/nm46n.png
#   inflating: captcha_images_v2/x7746.png
#  extracting: captcha_images_v2/4d22m.png
#   inflating: captcha_images_v2/6ng6w.png
#  extracting: captcha_images_v2/2nx38.png
#  extracting: captcha_images_v2/dfnx4.png
#  extracting: captcha_images_v2/fcmem.png
#   inflating: captcha_images_v2/gc83b.png
#  extracting: captcha_images_v2/n5x2n.png
#  extracting: captcha_images_v2/cnwyc.png
#  extracting: captcha_images_v2/8gecm.png
#  extracting: captcha_images_v2/fc6xb.png
#   inflating: captcha_images_v2/6n5fd.png
#  extracting: captcha_images_v2/6f2yc.png
#  extracting: captcha_images_v2/42xpy.png
#  extracting: captcha_images_v2/c5xne.png
#  extracting: captcha_images_v2/by5y3.png
#  extracting: captcha_images_v2/2ycn8.png
#  extracting: captcha_images_v2/n4cpy.png
#  extracting: captcha_images_v2/pf4nb.png
#  extracting: captcha_images_v2/378e5.png
#   inflating: captcha_images_v2/pym7p.png
#   inflating: captcha_images_v2/34b84.png
#  extracting: captcha_images_v2/d66cn.png
#  extracting: captcha_images_v2/nbwpn.png
#  extracting: captcha_images_v2/7pn5g.png
#  extracting: captcha_images_v2/y2xg4.png
#  extracting: captcha_images_v2/nwncn.png
#  extracting: captcha_images_v2/ebcbx.png
#   inflating: captcha_images_v2/43mn5.png
#  extracting: captcha_images_v2/4gb3f.png
#   inflating: captcha_images_v2/5x7x5.png
#  extracting: captcha_images_v2/gfxcc.png
#  extracting: captcha_images_v2/fy2nd.png
#   inflating: captcha_images_v2/d4n82.png
#  extracting: captcha_images_v2/nny5e.png
#  extracting: captcha_images_v2/dnne7.png
#  extracting: captcha_images_v2/p2ym2.png
#  extracting: captcha_images_v2/f858x.png
#  extracting: captcha_images_v2/dn26n.png
#  extracting: captcha_images_v2/xxw44.png
#  extracting: captcha_images_v2/5mnpd.png
#  extracting: captcha_images_v2/gp7c5.png
#  extracting: captcha_images_v2/d2nbn.png
#  extracting: captcha_images_v2/b5pnn.png
#  extracting: captcha_images_v2/c753e.png
#  extracting: captcha_images_v2/e46yw.png
#   inflating: captcha_images_v2/5p3mm.png
#  extracting: captcha_images_v2/8w875.png
#  extracting: captcha_images_v2/ny3dw.png
#  extracting: captcha_images_v2/efgx5.png
#   inflating: captcha_images_v2/32cnn.png
#  extracting: captcha_images_v2/d22n7.png
#   inflating: captcha_images_v2/8d2nd.png
#   inflating: captcha_images_v2/fnbfw.png
#  extracting: captcha_images_v2/7gnge.png
#  extracting: captcha_images_v2/e25xg.png
#   inflating: captcha_images_v2/pp546.png
#  extracting: captcha_images_v2/w46ep.png
#  extracting: captcha_images_v2/3g2w6.png
#   inflating: captcha_images_v2/gm2c2.png
#  extracting: captcha_images_v2/6ecbn.png
#   inflating: captcha_images_v2/n2by7.png
#   inflating: captcha_images_v2/cdfen.png
#   inflating: captcha_images_v2/6dd2y.png
#  extracting: captcha_images_v2/dce8y.png
#  extracting: captcha_images_v2/bmxpe.png
#  extracting: captcha_images_v2/x347n.png
#  extracting: captcha_images_v2/n7enn.png
#  extracting: captcha_images_v2/5nnff.png
#  extracting: captcha_images_v2/e7nx4.png
#   inflating: captcha_images_v2/5bb66.png
#  extracting: captcha_images_v2/e2d66.png
#  extracting: captcha_images_v2/wb3ed.png
#  extracting: captcha_images_v2/w48cw.png
#  extracting: captcha_images_v2/dw3nn.png
#   inflating: captcha_images_v2/bw5ym.png
#   inflating: captcha_images_v2/b84xc.png
#  extracting: captcha_images_v2/677g3.png
#  extracting: captcha_images_v2/gxxpf.png
#   inflating: captcha_images_v2/e7x45.png
#   inflating: captcha_images_v2/245y5.png
#  extracting: captcha_images_v2/ewcf5.png
#  extracting: captcha_images_v2/62nb3.png
#  extracting: captcha_images_v2/bny4w.png
#  extracting: captcha_images_v2/g2577.png
#  extracting: captcha_images_v2/23mdg.png
#  extracting: captcha_images_v2/d22y5.png
#  extracting: captcha_images_v2/fg7mg.png
#  extracting: captcha_images_v2/47e4p.png
#  extracting: captcha_images_v2/nb45d.png
#   inflating: captcha_images_v2/gpnxn.png
#  extracting: captcha_images_v2/e6m6p.png
#   inflating: captcha_images_v2/d75b5.png
#  extracting: captcha_images_v2/n5w5g.png
#   inflating: captcha_images_v2/w8f36.png
#  extracting: captcha_images_v2/3dgmf.png
#  extracting: captcha_images_v2/52447.png
#  extracting: captcha_images_v2/x3deb.png
#  extracting: captcha_images_v2/een23.png
#  extracting: captcha_images_v2/2bg48.png
#  extracting: captcha_images_v2/nxc83.png
#   inflating: captcha_images_v2/5mf7c.png
#   inflating: captcha_images_v2/efx34.png
#  extracting: captcha_images_v2/gewfy.png
#  extracting: captcha_images_v2/6b46g.png
#   inflating: captcha_images_v2/pm363.png
#   inflating: captcha_images_v2/4yc85.png
#  extracting: captcha_images_v2/g6n7x.png
#  extracting: captcha_images_v2/377xx.png
#  extracting: captcha_images_v2/3b4we.png
#  extracting: captcha_images_v2/xce8d.png
#  extracting: captcha_images_v2/pmg55.png
#  extracting: captcha_images_v2/5nggg.png
#   inflating: captcha_images_v2/5mgn4.png
#  extracting: captcha_images_v2/defyx.png
#   inflating: captcha_images_v2/8c23f.png
#  extracting: captcha_images_v2/nfcb5.png
#  extracting: captcha_images_v2/x7422.png
#   inflating: captcha_images_v2/gw53m.png
#  extracting: captcha_images_v2/cb8cf.png
#   inflating: captcha_images_v2/6e554.png
#  extracting: captcha_images_v2/5pm6b.png
#  extracting: captcha_images_v2/nnn5p.png
#  extracting: captcha_images_v2/f6ww8.png
#  extracting: captcha_images_v2/5325m.png
#  extracting: captcha_images_v2/d3ycn.png
#  extracting: captcha_images_v2/c4bny.png
#  extracting: captcha_images_v2/x775w.png
#  extracting: captcha_images_v2/b685n.png
#  extracting: captcha_images_v2/5bg8f.png
#  extracting: captcha_images_v2/xxbm5.png
#  extracting: captcha_images_v2/6gnm3.png
#  extracting: captcha_images_v2/gecmf.png
#   inflating: captcha_images_v2/nxx25.png
#  extracting: captcha_images_v2/5np4m.png
#  extracting: captcha_images_v2/dnmd8.png
#  extracting: captcha_images_v2/nd5wg.png
#   inflating: captcha_images_v2/n373n.png
#   inflating: captcha_images_v2/pm47f.png
#  extracting: captcha_images_v2/yew6p.png
#   inflating: captcha_images_v2/2en7g.png
#  extracting: captcha_images_v2/3n7mx.png
#  extracting: captcha_images_v2/pybee.png
#   inflating: captcha_images_v2/n7meb.png
#  extracting: captcha_images_v2/m3b5p.png
#  extracting: captcha_images_v2/c86md.png
#  extracting: captcha_images_v2/mg5nn.png
#  extracting: captcha_images_v2/bd3b7.png
#  extracting: captcha_images_v2/8xef7.png
#  extracting: captcha_images_v2/gfp54.png
#  extracting: captcha_images_v2/fpw76.png
#  extracting: captcha_images_v2/mmg2m.png
#  extracting: captcha_images_v2/dbex3.png
#  extracting: captcha_images_v2/38n57.png
#  extracting: captcha_images_v2/n8pfe.png
#  extracting: captcha_images_v2/nc4yg.png
#  extracting: captcha_images_v2/5wddw.png
#   inflating: captcha_images_v2/8nn73.png
#   inflating: captcha_images_v2/37ep6.png
#   inflating: captcha_images_v2/xnfx5.png
#   inflating: captcha_images_v2/e76n4.png
#  extracting: captcha_images_v2/x6pdb.png
#  extracting: captcha_images_v2/xbcbx.png
#  extracting: captcha_images_v2/3x5fm.png
#  extracting: captcha_images_v2/44c22.png
#   inflating: captcha_images_v2/4dgf7.png
#  extracting: captcha_images_v2/6end3.png
#  extracting: captcha_images_v2/b28g8.png
#   inflating: captcha_images_v2/g8gnd.png
#  extracting: captcha_images_v2/pcm7f.png
#  extracting: captcha_images_v2/4exnn.png
#   inflating: captcha_images_v2/3ye2e.png
#   inflating: captcha_images_v2/bf52c.png
#  extracting: captcha_images_v2/b55d6.png
#  extracting: captcha_images_v2/xngxc.png
#  extracting: captcha_images_v2/pgmn2.png
#  extracting: captcha_images_v2/2npg6.png
#  extracting: captcha_images_v2/xfn6n.png
#  extracting: captcha_images_v2/xcmbp.png
#   inflating: captcha_images_v2/f5cm2.png
#  extracting: captcha_images_v2/d8xcn.png
#  extracting: captcha_images_v2/dn2ym.png
#  extracting: captcha_images_v2/c2g4d.png
#  extracting: captcha_images_v2/53wb8.png
#  extracting: captcha_images_v2/7f8b3.png
#  extracting: captcha_images_v2/8b735.png
#   inflating: captcha_images_v2/7dyww.png
#  extracting: captcha_images_v2/5nm6d.png
#  extracting: captcha_images_v2/feyc8.png
#  extracting: captcha_images_v2/gwn53.png
#  extracting: captcha_images_v2/3fbxd.png
#   inflating: captcha_images_v2/gw468.png
#  extracting: captcha_images_v2/f2fge.png
#   inflating: captcha_images_v2/cgcgb.png
#  extracting: captcha_images_v2/fxpw3.png
#  extracting: captcha_images_v2/ndyfe.png
#  extracting: captcha_images_v2/7e2y7.png
#  extracting: captcha_images_v2/n4wwn.png
#  extracting: captcha_images_v2/8n56m.png
#  extracting: captcha_images_v2/f22bn.png
#   inflating: captcha_images_v2/25w53.png
#  extracting: captcha_images_v2/44xe8.png
#  extracting: captcha_images_v2/2wx73.png
#   inflating: captcha_images_v2/mb4en.png
#  extracting: captcha_images_v2/x2cnn.png
#   inflating: captcha_images_v2/gc277.png
#  extracting: captcha_images_v2/e667x.png
#  extracting: captcha_images_v2/w4cdc.png
#  extracting: captcha_images_v2/mwxwp.png
#  extracting: captcha_images_v2/6n6gg.png
#   inflating: captcha_images_v2/mdyp7.png
#  extracting: captcha_images_v2/8y63f.png
#  extracting: captcha_images_v2/gy5bf.png
#  extracting: captcha_images_v2/6m5eg.png
#   inflating: captcha_images_v2/85dxn.png
#   inflating: captcha_images_v2/wnpec.png
#  extracting: captcha_images_v2/8d8ep.png
#   inflating: captcha_images_v2/2cgyx.png
#  extracting: captcha_images_v2/3xng6.png
#  extracting: captcha_images_v2/675p3.png
#  extracting: captcha_images_v2/bp6mw.png
#  extracting: captcha_images_v2/yd3m3.png
#  extracting: captcha_images_v2/cx3wg.png
#  extracting: captcha_images_v2/5bnd7.png
#  extracting: captcha_images_v2/ddcdd.png
#  extracting: captcha_images_v2/p8wwf.png
#  extracting: captcha_images_v2/gnbde.png
#   inflating: captcha_images_v2/mbp2y.png
#  extracting: captcha_images_v2/mxyxw.png
#  extracting: captcha_images_v2/n4xx5.png
#  extracting: captcha_images_v2/73mnx.png
#  extracting: captcha_images_v2/d8dce.png
#   inflating: captcha_images_v2/cnex4.png
#  extracting: captcha_images_v2/dnxdp.png
#  extracting: captcha_images_v2/28x47.png
#  extracting: captcha_images_v2/3ndxd.png
#  extracting: captcha_images_v2/nbf8m.png
#  extracting: captcha_images_v2/dbfen.png
#  extracting: captcha_images_v2/pdcp4.png
#   inflating: captcha_images_v2/4gycb.png
#  extracting: captcha_images_v2/xmcym.png
#  extracting: captcha_images_v2/fp3wy.png
#  extracting: captcha_images_v2/y53c2.png
#   inflating: captcha_images_v2/c482b.png
#  extracting: captcha_images_v2/fg8n4.png
#  extracting: captcha_images_v2/gbxyy.png
#   inflating: captcha_images_v2/bpwd7.png
#  extracting: captcha_images_v2/57wdp.png
#   inflating: captcha_images_v2/c2fb7.png
#  extracting: captcha_images_v2/c6f8g.png
#   inflating: captcha_images_v2/d666m.png
#  extracting: captcha_images_v2/gfbx6.png
#   inflating: captcha_images_v2/7fde7.png
#  extracting: captcha_images_v2/b3xpn.png
#  extracting: captcha_images_v2/m75bf.png
#  extracting: captcha_images_v2/243mm.png
#  extracting: captcha_images_v2/8gf7n.png
#  extracting: captcha_images_v2/x8xnp.png
#  extracting: captcha_images_v2/b4ncn.png
#  extracting: captcha_images_v2/pe4xn.png
#   inflating: captcha_images_v2/ep85x.png
#   inflating: captcha_images_v2/nb267.png
#   inflating: captcha_images_v2/8684m.png
#   inflating: captcha_images_v2/gn2d3.png
#  extracting: captcha_images_v2/4743p.png
#  extracting: captcha_images_v2/5ep3n.png
#  extracting: captcha_images_v2/c4527.png
#  extracting: captcha_images_v2/72m6f.png
#  extracting: captcha_images_v2/cdmn8.png
#   inflating: captcha_images_v2/ddcne.png
#  extracting: captcha_images_v2/5yxgp.png
#  extracting: captcha_images_v2/gxx2p.png
#  extracting: captcha_images_v2/4m2w5.png
#   inflating: captcha_images_v2/cfn53.png
#  extracting: captcha_images_v2/3w2bw.png
#   inflating: captcha_images_v2/mcg43.png
#   inflating: captcha_images_v2/7xd5m.png
#  extracting: captcha_images_v2/6wb76.png
#   inflating: captcha_images_v2/325fb.png
#  extracting: captcha_images_v2/nf8b8.png
#  extracting: captcha_images_v2/wnmyn.png
#  extracting: captcha_images_v2/wd2gb.png
#  extracting: captcha_images_v2/nfndw.png
#  extracting: captcha_images_v2/4nnf3.png
#  extracting: captcha_images_v2/ddmyg.png
#  extracting: captcha_images_v2/3ym7f.png
#  extracting: captcha_images_v2/yw7ny.png
#  extracting: captcha_images_v2/ny3nn.png
#  extracting: captcha_images_v2/6p2ge.png
#  extracting: captcha_images_v2/4n2yg.png
#  extracting: captcha_images_v2/6ydyp.png
#  extracting: captcha_images_v2/m2576.png
#  extracting: captcha_images_v2/b5fm7.png
#   inflating: captcha_images_v2/m3588.png
#  extracting: captcha_images_v2/m6n4x.png
#  extracting: captcha_images_v2/6fgdw.png
#   inflating: captcha_images_v2/88y52.png
#  extracting: captcha_images_v2/b5nmm.png
#   inflating: captcha_images_v2/gc2wd.png
#  extracting: captcha_images_v2/y4g3b.png
#  extracting: captcha_images_v2/d7en3.png
#   inflating: captcha_images_v2/eppg3.png
#   inflating: captcha_images_v2/5ywwf.png
#  extracting: captcha_images_v2/nngxc.png
#  extracting: captcha_images_v2/2xc2n.png
#   inflating: captcha_images_v2/8db67.png
#  extracting: captcha_images_v2/8pfxx.png
#  extracting: captcha_images_v2/76n7p.png
#  extracting: captcha_images_v2/cy3nw.png
#  extracting: captcha_images_v2/mwdf6.png
#  extracting: captcha_images_v2/6bdn5.png
#  extracting: captcha_images_v2/46mbm.png
#  extracting: captcha_images_v2/6b4w6.png
#  extracting: captcha_images_v2/g3ex3.png
#  extracting: captcha_images_v2/dmxp8.png
#  extracting: captcha_images_v2/g78gn.png
#  extracting: captcha_images_v2/w75w8.png
#  extracting: captcha_images_v2/gy8xb.png
#  extracting: captcha_images_v2/pf5ng.png
#  extracting: captcha_images_v2/egxmp.png
#   inflating: captcha_images_v2/x37bf.png
#  extracting: captcha_images_v2/pwn5e.png
#  extracting: captcha_images_v2/556wd.png
#  extracting: captcha_images_v2/xfg65.png
#  extracting: captcha_images_v2/xyyyw.png
#  extracting: captcha_images_v2/cfc2y.png
#  extracting: captcha_images_v2/excmn.png
#  extracting: captcha_images_v2/6xpme.png
#  extracting: captcha_images_v2/74eyg.png
#  extracting: captcha_images_v2/3n2b4.png
#  extracting: captcha_images_v2/fp382.png
#  extracting: captcha_images_v2/8ne4g.png
#  extracting: captcha_images_v2/ygfwe.png
#  extracting: captcha_images_v2/x38fn.png
#   inflating: captcha_images_v2/2n73f.png
#  extracting: captcha_images_v2/4n3mn.png
#  extracting: captcha_images_v2/2w4y7.png
#  extracting: captcha_images_v2/8fexn.png
#  extracting: captcha_images_v2/mxnw4.png
#  extracting: captcha_images_v2/gd4mf.png
#  extracting: captcha_images_v2/n8ydd.png
#  extracting: captcha_images_v2/mc35n.png
#   inflating: captcha_images_v2/fncnb.png
#  extracting: captcha_images_v2/yyg5g.png
#   inflating: captcha_images_v2/bgd4m.png
#  extracting: captcha_images_v2/pcpg6.png
#  extracting: captcha_images_v2/b2nen.png
#  extracting: captcha_images_v2/byc82.png
#   inflating: captcha_images_v2/2gyb6.png
#  extracting: captcha_images_v2/dpbyd.png
#  extracting: captcha_images_v2/7g3nf.png
#  extracting: captcha_images_v2/nbmx7.png
#  extracting: captcha_images_v2/6mn8n.png
#  extracting: captcha_images_v2/x277e.png
#  extracting: captcha_images_v2/3ygde.png
#  extracting: captcha_images_v2/nfd8g.png
#  extracting: captcha_images_v2/nbwnn.png
#   inflating: captcha_images_v2/c8n8c.png
#  extracting: captcha_images_v2/8eggg.png
#  extracting: captcha_images_v2/7fmcy.png
#  extracting: captcha_images_v2/enpw2.png
#  extracting: captcha_images_v2/5mfff.png
#   inflating: captcha_images_v2/4ynf3.png
#  extracting: captcha_images_v2/ee8fg.png
#  extracting: captcha_images_v2/ny5dp.png
#  extracting: captcha_images_v2/77387.png
#  extracting: captcha_images_v2/p2x7x.png
#  extracting: captcha_images_v2/y48c3.png
#  extracting: captcha_images_v2/efg72.png
#   inflating: captcha_images_v2/pgwnp.png
#   inflating: captcha_images_v2/n7g4f.png
#   inflating: captcha_images_v2/pg4bf.png
#  extracting: captcha_images_v2/pmd3w.png
#   inflating: captcha_images_v2/8w754.png
#   inflating: captcha_images_v2/823p2.png
#   inflating: captcha_images_v2/8n4n8.png
#  extracting: captcha_images_v2/dyp7n.png
#  extracting: captcha_images_v2/m5meg.png
#  extracting: captcha_images_v2/ffpxf.png
#  extracting: captcha_images_v2/nxn4f.png
#   inflating: captcha_images_v2/bw44w.png
#  extracting: captcha_images_v2/befbd.png
#  extracting: captcha_images_v2/7xcyd.png
#  extracting: captcha_images_v2/p7fyp.png
#  extracting: captcha_images_v2/n7ff2.png
#  extracting: captcha_images_v2/be3bp.png
#  extracting: captcha_images_v2/d4ppy.png

# %%
import os

os.environ["KERAS_BACKEND"] = "tensorflow"

import numpy as np
import matplotlib.pyplot as plt

from pathlib import Path

import tensorflow as tf
import keras
from keras import layers

# %%
data_dir = Path("./captcha_images_v2/")

# Get list of all the images
images = sorted(list(map(str, list(data_dir.glob("*.png")))))
labels = [img.split(os.path.sep)[-1].split(".png")[0] for img in images]
characters = set(char for label in labels for char in label)
characters = sorted(list(characters))

print("Number of images found: ", len(images))
print("Number of labels found: ", len(labels))
print("Number of unique characters: ", len(characters))
print("Characters present: ", characters)

# Batch size for training and validation
batch_size = 16

# Desired image dimensions
img_width = 200
img_height = 50

downsample_factor = 4

# Maximum length of any captcha in the dataset
max_length = max([len(label) for label in labels])
# Out:
# Number of images found:  1040
# Number of labels found:  1040
# Number of unique characters:  19
# Characters present:  ['2', '3', '4', '5', '6', '7', '8', 'b', 'c', 'd', 'e', 'f', 'g', 'm', 'n', 'p', 'w', 'x', 'y']

# %% [markdown]
# # Data Preprocessing

# %%
char_to_num = layers.StringLookup(vocabulary=list(characters), mask_token=None)

# Mapping integers back to original characters
num_to_char = layers.StringLookup(
    vocabulary=char_to_num.get_vocabulary(), mask_token=None, invert=True
)


def split_data(images, labels, train_size=0.9, shuffle=True):
    # 1. Get the total size of the dataset
    size = len(images)
    # 2. Make an indices array and shuffle it, if required
    indices = tf.range(size)
    if shuffle:
        indices = tf.random.shuffle(indices)
    # 3. Get the size of training samples
    train_samples = int(size * train_size)
    # 4. Split data into training and validation sets
    x_train, y_train = images[indices[:train_samples]], labels[indices[:train_samples]]
    x_valid, y_valid = images[indices[train_samples:]], labels[indices[train_samples:]]
    return x_train, x_valid, y_train, y_valid


# Splitting data into training and validation sets
x_train, x_valid, y_train, y_valid = split_data(np.array(images), np.array(labels))


def encode_single_sample(img_path, label):
    # 1. Read image
    img = tf.io.read_file(img_path)
    # 2. Decode and convert to grayscale
    img = tf.io.decode_png(img, channels=1)
    # 3. Convert to float32 in [0, 1] range
    img = tf.image.convert_image_dtype(img, tf.float32)
    # 4. Resize to the desired size
    img = tf.image.resize(img, [img_height, img_width])
    # 5. Transpose the image because we want the time
    # dimension to correspond to the width of the image.
    img = tf.transpose(img, perm=[1, 0, 2])
    # 6. Map the characters in label to numbers
    label = char_to_num(tf.strings.unicode_split(label, input_encoding="UTF-8"))
    # 7. Return a dict as our model is expecting two inputs
    return {"image": img, "label": label}

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.15.0

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train))
train_dataset = (
    train_dataset.map(encode_single_sample, num_parallel_calls=tf.data.AUTOTUNE)
    .batch(batch_size)
    .prefetch(buffer_size=tf.data.AUTOTUNE)
)

validation_dataset = tf.data.Dataset.from_tensor_slices((x_valid, y_valid))
validation_dataset = (
    validation_dataset.map(encode_single_sample, num_parallel_calls=tf.data.AUTOTUNE)
    .batch(batch_size)
    .prefetch(buffer_size=tf.data.AUTOTUNE)
)

# %% [markdown]
# # Visualize the data

# %%
_, ax = plt.subplots(4, 4, figsize=(10, 5))
for batch in train_dataset.take(1):
    images = batch["image"]
    labels = batch["label"]
    for i in range(16):
        img = (images[i] * 255).numpy().astype("uint8")
        label = tf.strings.reduce_join(num_to_char(labels[i])).numpy().decode("utf-8")
        ax[i // 4, i % 4].imshow(img[:, :, 0].T, cmap="gray")
        ax[i // 4, i % 4].set_title(label)
        ax[i // 4, i % 4].axis("off")
plt.show()

# %% [markdown]
# # Model

# %%
def ctc_batch_cost(y_true, y_pred, input_length, label_length):
    label_length = tf.cast(tf.squeeze(label_length, axis=-1), dtype="int32")
    input_length = tf.cast(tf.squeeze(input_length, axis=-1), dtype="int32")
    sparse_labels = tf.cast(
        ctc_label_dense_to_sparse(y_true, label_length), dtype="int32"
    )

    y_pred = tf.math.log(tf.transpose(y_pred, perm=[1, 0, 2]) + keras.backend.epsilon())

    return tf.expand_dims(
        tf.compat.v1.nn.ctc_loss(
            inputs=y_pred, labels=sparse_labels, sequence_length=input_length
        ),
        1,
    )


def ctc_label_dense_to_sparse(labels, label_lengths):
    label_shape = tf.shape(labels)
    num_batches_tns = tf.stack([label_shape[0]])
    max_num_labels_tns = tf.stack([label_shape[1]])

    def range_less_than(old_input, current_input):
        return tf.expand_dims(tf.range(tf.shape(old_input)[1]), 0) < tf.fill(
            max_num_labels_tns, current_input
        )

    init = tf.cast(tf.fill([1, label_shape[1]], 0), dtype="bool")
    dense_mask = tf.compat.v1.scan(
        range_less_than, label_lengths, initializer=init, parallel_iterations=1
    )
    dense_mask = dense_mask[:, 0, :]

    label_array = tf.reshape(
        tf.tile(tf.range(0, label_shape[1]), num_batches_tns), label_shape
    )
    label_ind = tf.compat.v1.boolean_mask(label_array, dense_mask)

    batch_array = tf.transpose(
        tf.reshape(
            tf.tile(tf.range(0, label_shape[0]), max_num_labels_tns),
            tf.reverse(label_shape, [0]),
        )
    )
    batch_ind = tf.compat.v1.boolean_mask(batch_array, dense_mask)
    indices = tf.transpose(
        tf.reshape(tf.concat([batch_ind, label_ind], axis=0), [2, -1])
    )

    vals_sparse = tf.compat.v1.gather_nd(labels, indices)

    return tf.SparseTensor(
        tf.cast(indices, dtype="int64"),
        vals_sparse,
        tf.cast(label_shape, dtype="int64")
    )


class CTCLayer(layers.Layer):
    def __init__(self, name=None):
        super().__init__(name=name)
        self.loss_fn = ctc_batch_cost

    def call(self, y_true, y_pred):
        # Compute the training-time loss value and add it
        # to the layer using `self.add_loss()`.
        batch_len = tf.cast(tf.shape(y_true)[0], dtype="int64")
        input_length = tf.cast(tf.shape(y_pred)[1], dtype="int64")
        label_length = tf.cast(tf.shape(y_true)[1], dtype="int64")

        input_length = input_length * tf.ones(shape=(batch_len, 1), dtype="int64")
        label_length = label_length * tf.ones(shape=(batch_len, 1), dtype="int64")

        loss = self.loss_fn(y_true, y_pred, input_length, label_length)
        self.add_loss(loss)

        # At test time, just return the computed predictions
        return y_pred


def build_model():
    # Inputs to the model
    input_img = layers.Input(
        shape=(img_width, img_height, 1), name="image", dtype="float32"
    )
    labels = layers.Input(name="label", shape=(None,), dtype="float32")

    # First conv block
    x = layers.Conv2D(
        32,
        (3, 3),
        activation="relu",
        kernel_initializer="he_normal",
        padding="same",
        name="Conv1",
    )(input_img)
    x = layers.MaxPooling2D((2, 2), name="pool1")(x)

    # Second conv block
    x = layers.Conv2D(
        64,
        (3, 3),
        activation="relu",
        kernel_initializer="he_normal",
        padding="same",
        name="Conv2",
    )(x)
    x = layers.MaxPooling2D((2, 2), name="pool2")(x)


    new_shape = ((img_width // 4), (img_height // 4) * 64)
    x = layers.Reshape(target_shape=new_shape, name="reshape")(x)
    x = layers.Dense(64, activation="relu", name="dense1")(x)
    x = layers.Dropout(0.2)(x)

    # RNNs
    x = layers.Bidirectional(layers.LSTM(128, return_sequences=True, dropout=0.25))(x)
    x = layers.Bidirectional(layers.LSTM(64, return_sequences=True, dropout=0.25))(x)

    # Output layer
    x = layers.Dense(
        len(char_to_num.get_vocabulary()) + 1, activation="softmax", name="dense2"
    )(x)

    # Add CTC layer for calculating CTC loss at each step
    output = CTCLayer(name="ctc_loss")(labels, x)

    # Define the model
    model = keras.models.Model(
        inputs=[input_img, labels], outputs=output, name="ocr_model_v1"
    )
    # Optimizer
    opt = keras.optimizers.Adam()
    # Compile the model and return
    model.compile(optimizer=opt)
    return model


# Get the model
model = build_model()
model.summary()
# Out:
# Model: "ocr_model_v1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  image (InputLayer)          [(None, 200, 50, 1)]         0         []
#
#  Conv1 (Conv2D)              (None, 200, 50, 32)          320       ['image[0][0]']
#
#  pool1 (MaxPooling2D)        (None, 100, 25, 32)          0         ['Conv1[0][0]']
#
#  Conv2 (Conv2D)              (None, 100, 25, 64)          18496     ['pool1[0][0]']
#
#  pool2 (MaxPooling2D)        (None, 50, 12, 64)           0         ['Conv2[0][0]']
#
#  reshape (Reshape)           (None, 50, 768)              0         ['pool2[0][0]']
#
#  dense1 (Dense)              (None, 50, 64)               49216     ['reshape[0][0]']
#
#  dropout_4 (Dropout)         (None, 50, 64)               0         ['dense1[0][0]']
#
#  bidirectional_8 (Bidirecti  (None, 50, 256)              197632    ['dropout_4[0][0]']
#  onal)
#
#  bidirectional_9 (Bidirecti  (None, 50, 128)              164352    ['bidirectional_8[0][0]']
#  onal)
#
#  label (InputLayer)          [(None, None)]               0         []
#
#  dense2 (Dense)              (None, 50, 21)               2709      ['bidirectional_9[0][0]']
#
#  ctc_loss (CTCLayer)         (None, 50, 21)               0         ['label[0][0]',
#                                                                      'dense2[0][0]']
#
# ==================================================================================================
# Total params: 432725 (1.65 MB)
# Trainable params: 432725 (1.65 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %% [markdown]
# # Train

# %%
epochs = 100
early_stopping_patience = 10
# Add early stopping
early_stopping = keras.callbacks.EarlyStopping(
    monitor="val_loss", patience=early_stopping_patience, restore_best_weights=True
)

# Train the model
history = model.fit(
    train_dataset,
    validation_data=validation_dataset,
    epochs=epochs,
    callbacks=[early_stopping],
)
# Out:
# Epoch 1/100
# 59/59 [==============================] - 37s 446ms/step - loss: 19.5672 - val_loss: 16.3776
# Epoch 2/100
# 59/59 [==============================] - 25s 412ms/step - loss: 16.3656 - val_loss: 16.3717
# Epoch 3/100
# 59/59 [==============================] - 24s 401ms/step - loss: 16.3528 - val_loss: 16.3789
# Epoch 4/100
# 59/59 [==============================] - 24s 402ms/step - loss: 16.3423 - val_loss: 16.3881
# Epoch 5/100
# 59/59 [==============================] - 25s 430ms/step - loss: 16.3339 - val_loss: 16.3953
# Epoch 6/100
# 59/59 [==============================] - 25s 423ms/step - loss: 16.3228 - val_loss: 16.3649
# Epoch 7/100
# 59/59 [==============================] - 29s 491ms/step - loss: 16.3056 - val_loss: 16.3469
# Epoch 8/100
# 59/59 [==============================] - 23s 398ms/step - loss: 16.2795 - val_loss: 16.3210
# Epoch 9/100
# 59/59 [==============================] - 24s 414ms/step - loss: 16.2221 - val_loss: 16.2539
# Epoch 10/100
# 59/59 [==============================] - 27s 461ms/step - loss: 16.1518 - val_loss: 16.2247
# Epoch 11/100
# 59/59 [==============================] - 24s 406ms/step - loss: 16.0826 - val_loss: 16.1926
# Epoch 12/100
# 59/59 [==============================] - 24s 416ms/step - loss: 16.0184 - val_loss: 16.1878
# Epoch 13/100
# 59/59 [==============================] - 25s 422ms/step - loss: 15.9645 - val_loss: 16.2086
# Epoch 14/100
# 59/59 [==============================] - 22s 371ms/step - loss: 15.8722 - val_loss: 16.2311
# Epoch 15/100
# 59/59 [==============================] - 24s 402ms/step - loss: 15.7514 - val_loss: 16.0397
# Epoch 16/100
# 59/59 [==============================] - 24s 406ms/step - loss: 15.6090 - val_loss: 15.9016
# Epoch 17/100
# 59/59 [==============================] - 24s 410ms/step - loss: 15.4962 - val_loss: 15.6967
# Epoch 18/100
# 59/59 [==============================] - 23s 396ms/step - loss: 15.2937 - val_loss: 15.4646
# Epoch 19/100
# 59/59 [==============================] - 24s 405ms/step - loss: 15.0895 - val_loss: 15.2885
# Epoch 20/100
# 59/59 [==============================] - 24s 401ms/step - loss: 14.8802 - val_loss: 14.9319
# Epoch 21/100
# 59/59 [==============================] - 22s 371ms/step - loss: 14.6307 - val_loss: 14.8092
# Epoch 22/100
# 59/59 [==============================] - 27s 454ms/step - loss: 14.4084 - val_loss: 14.7007
# Epoch 23/100
# 59/59 [==============================] - 24s 410ms/step - loss: 14.2216 - val_loss: 14.4878
# Epoch 24/100
# 59/59 [==============================] - 24s 403ms/step - loss: 14.0327 - val_loss: 14.2683
# Epoch 25/100
# 59/59 [==============================] - 24s 400ms/step - loss: 13.7575 - val_loss: 14.0455
# Epoch 26/100
# 59/59 [==============================] - 24s 405ms/step - loss: 13.5702 - val_loss: 13.8345
# Epoch 27/100
# 59/59 [==============================] - 23s 396ms/step - loss: 13.2118 - val_loss: 13.4592
# Epoch 28/100
# 59/59 [==============================] - 24s 415ms/step - loss: 12.9306 - val_loss: 13.2861
# Epoch 29/100
# 59/59 [==============================] - 24s 408ms/step - loss: 12.6620 - val_loss: 12.9601
# Epoch 30/100
# 59/59 [==============================] - 24s 401ms/step - loss: 12.3499 - val_loss: 12.5771
# Epoch 31/100
# 59/59 [==============================] - 25s 417ms/step - loss: 12.0724 - val_loss: 12.5395
# Epoch 32/100
# 59/59 [==============================] - 24s 407ms/step - loss: 11.7454 - val_loss: 12.0421
# Epoch 33/100
# 59/59 [==============================] - 26s 448ms/step - loss: 11.4624 - val_loss: 11.6679
# Epoch 34/100
# 59/59 [==============================] - 24s 408ms/step - loss: 11.1918 - val_loss: 11.4601
# Epoch 35/100
# 59/59 [==============================] - 24s 407ms/step - loss: 10.8052 - val_loss: 11.3430
# Epoch 36/100
# 59/59 [==============================] - 24s 414ms/step - loss: 10.5445 - val_loss: 10.9164
# Epoch 37/100
# 59/59 [==============================] - 24s 407ms/step - loss: 10.2550 - val_loss: 10.8809
# Epoch 38/100
# 59/59 [==============================] - 24s 411ms/step - loss: 9.8945 - val_loss: 10.4719
# Epoch 39/100
# 59/59 [==============================] - 24s 407ms/step - loss: 9.6185 - val_loss: 10.1443
# Epoch 40/100
# 59/59 [==============================] - 25s 419ms/step - loss: 9.3659 - val_loss: 9.9376
# Epoch 41/100
# 59/59 [==============================] - 24s 410ms/step - loss: 9.0813 - val_loss: 9.8499
# Epoch 42/100
# 59/59 [==============================] - 24s 403ms/step - loss: 8.7272 - val_loss: 9.4554
# Epoch 43/100
# 59/59 [==============================] - 24s 398ms/step - loss: 8.4644 - val_loss: 9.2795
# Epoch 44/100
# 59/59 [==============================] - 22s 374ms/step - loss: 8.0881 - val_loss: 8.9534
# Epoch 45/100
# 59/59 [==============================] - 24s 403ms/step - loss: 7.7548 - val_loss: 8.5718
# Epoch 46/100
# 59/59 [==============================] - 24s 403ms/step - loss: 7.4834 - val_loss: 8.2483
# Epoch 47/100
# 59/59 [==============================] - 24s 401ms/step - loss: 7.1677 - val_loss: 8.0638
# Epoch 48/100
# 59/59 [==============================] - 24s 406ms/step - loss: 6.7738 - val_loss: 8.0563
# Epoch 49/100
# 59/59 [==============================] - 23s 385ms/step - loss: 6.5118 - val_loss: 7.7668
# Epoch 50/100
# 59/59 [==============================] - 24s 402ms/step - loss: 6.1695 - val_loss: 7.4816
# Epoch 51/100
# 59/59 [==============================] - 22s 372ms/step - loss: 5.8465 - val_loss: 7.2231
# Epoch 52/100
# 59/59 [==============================] - 24s 409ms/step - loss: 5.5703 - val_loss: 7.0278
# Epoch 53/100
# 59/59 [==============================] - 24s 401ms/step - loss: 5.1425 - val_loss: 6.7024
# Epoch 54/100
# 59/59 [==============================] - 24s 408ms/step - loss: 4.9295 - val_loss: 6.6992
# Epoch 55/100
# 59/59 [==============================] - 24s 400ms/step - loss: 4.7622 - val_loss: 6.5233
# Epoch 56/100
# 59/59 [==============================] - 24s 401ms/step - loss: 4.4794 - val_loss: 6.2489
# Epoch 57/100
# 59/59 [==============================] - 24s 399ms/step - loss: 4.5139 - val_loss: 6.1631
# Epoch 58/100
# 59/59 [==============================] - 24s 399ms/step - loss: 4.1196 - val_loss: 6.1571
# Epoch 59/100
# 59/59 [==============================] - 24s 399ms/step - loss: 3.8925 - val_loss: 6.0061
# Epoch 60/100
# 59/59 [==============================] - 24s 403ms/step - loss: 3.8070 - val_loss: 5.7767
# Epoch 61/100
# 59/59 [==============================] - 24s 400ms/step - loss: 3.6553 - val_loss: 5.8521
# Epoch 62/100
# 59/59 [==============================] - 24s 397ms/step - loss: 3.4203 - val_loss: 5.5438
# Epoch 63/100
# 59/59 [==============================] - 23s 384ms/step - loss: 3.2240 - val_loss: 5.5875
# Epoch 64/100
# 59/59 [==============================] - 22s 377ms/step - loss: 2.9999 - val_loss: 5.6370
# Epoch 65/100
# 59/59 [==============================] - 24s 400ms/step - loss: 2.8846 - val_loss: 5.4840
# Epoch 66/100
# 59/59 [==============================] - 24s 403ms/step - loss: 2.8407 - val_loss: 5.3363
# Epoch 67/100
# 59/59 [==============================] - 22s 373ms/step - loss: 2.6313 - val_loss: 5.3499
# Epoch 68/100
# 59/59 [==============================] - 24s 405ms/step - loss: 2.6525 - val_loss: 5.2898
# Epoch 69/100
# 59/59 [==============================] - 23s 387ms/step - loss: 2.4350 - val_loss: 5.3251
# Epoch 70/100
# 59/59 [==============================] - 22s 372ms/step - loss: 2.4550 - val_loss: 5.0741
# Epoch 71/100
# 59/59 [==============================] - 23s 390ms/step - loss: 2.3031 - val_loss: 5.2123
# Epoch 72/100
# 59/59 [==============================] - 23s 396ms/step - loss: 2.2084 - val_loss: 4.9941
# Epoch 73/100
# 59/59 [==============================] - 23s 398ms/step - loss: 2.1005 - val_loss: 5.3708
# Epoch 74/100
# 59/59 [==============================] - 22s 372ms/step - loss: 2.0045 - val_loss: 5.3666
# Epoch 75/100
# 59/59 [==============================] - 24s 400ms/step - loss: 1.9558 - val_loss: 5.2131
# Epoch 76/100
# 59/59 [==============================] - 23s 386ms/step - loss: 1.8166 - val_loss: 5.0209
# Epoch 77/100
# 59/59 [==============================] - 22s 379ms/step - loss: 1.7668 - val_loss: 5.1386
# Epoch 78/100
# 59/59 [==============================] - 24s 408ms/step - loss: 1.6911 - val_loss: 5.0819
# Epoch 79/100
# 59/59 [==============================] - 23s 398ms/step - loss: 1.6327 - val_loss: 5.2938
# Epoch 80/100
# 59/59 [==============================] - 22s 373ms/step - loss: 1.5829 - val_loss: 5.0682
# Epoch 81/100
# 59/59 [==============================] - 24s 414ms/step - loss: 1.5049 - val_loss: 5.5813
# Epoch 82/100
# 59/59 [==============================] - 22s 375ms/step - loss: 1.4739 - val_loss: 5.1883

# %%
def ctc_decode(y_pred, input_length, greedy=True, beam_width=100, top_paths=1):
    input_shape = tf.shape(y_pred)
    num_samples, num_steps = input_shape[0], input_shape[1]
    y_pred = tf.math.log(tf.transpose(y_pred, perm=[1, 0, 2]) + keras.backend.epsilon())
    input_length = tf.cast(input_length, dtype="int32")

    if greedy:
        (decoded, log_prob) = tf.nn.ctc_greedy_decoder(
            inputs=y_pred, sequence_length=input_length
        )
    else:
        (decoded, log_prob) = tf.compat.v1.nn.ctc_beam_search_decoder(
            inputs=y_pred,
            sequence_length=input_length,
            beam_width=beam_width,
            top_paths=top_paths,
        )
    decoded_dense = []
    for st in decoded:
        st = tf.SparseTensor(st.indices, st.values, (num_samples, num_steps))
        decoded_dense.append(tf.sparse.to_dense(sp_input=st, default_value=-1))
    return (decoded_dense, log_prob)


# Get the prediction model by extracting layers till the output layer
prediction_model = keras.models.Model(
    model.input[0], model.get_layer(name="dense2").output
)
prediction_model.summary()


# A utility function to decode the output of the network
def decode_batch_predictions(pred):
    input_len = np.ones(pred.shape[0]) * pred.shape[1]
    # Use greedy search. For complex tasks, you can use beam search
    results = ctc_decode(pred, input_length=input_len, greedy=True)[0][0][
        :, :max_length
    ]
    # Iterate over the results and get back the text
    output_text = []
    for res in results:
        res = tf.strings.reduce_join(num_to_char(res)).numpy().decode("utf-8")
        output_text.append(res)
    return output_text


#  Let's check results on some validation samples
for batch in validation_dataset.take(1):
    batch_images = batch["image"]
    batch_labels = batch["label"]

    preds = prediction_model.predict(batch_images)
    pred_texts = decode_batch_predictions(preds)

    orig_texts = []
    for label in batch_labels:
        label = tf.strings.reduce_join(num_to_char(label)).numpy().decode("utf-8")
        orig_texts.append(label)

    _, ax = plt.subplots(4, 4, figsize=(15, 5))
    for i in range(len(pred_texts)):
        img = (batch_images[i, :, :, 0] * 255).numpy().astype(np.uint8)
        img = img.T
        title = f"Prediction: {pred_texts[i]}"
        ax[i // 4, i % 4].imshow(img, cmap="gray")
        ax[i // 4, i % 4].set_title(title)
        ax[i // 4, i % 4].axis("off")
plt.show()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  image (InputLayer)          [(None, 200, 50, 1)]      0
#
#  Conv1 (Conv2D)              (None, 200, 50, 32)       320
#
#  pool1 (MaxPooling2D)        (None, 100, 25, 32)       0
#
#  Conv2 (Conv2D)              (None, 100, 25, 64)       18496
#
#  pool2 (MaxPooling2D)        (None, 50, 12, 64)        0
#
#  reshape (Reshape)           (None, 50, 768)           0
#
#  dense1 (Dense)              (None, 50, 64)            49216
#
#  dropout_4 (Dropout)         (None, 50, 64)            0
#
#  bidirectional_8 (Bidirecti  (None, 50, 256)           197632
#  onal)
#
#  bidirectional_9 (Bidirecti  (None, 50, 128)           164352
#  onal)
#
#  dense2 (Dense)              (None, 50, 21)            2709
#
# =================================================================
# Total params: 432725 (1.65 MB)
# Trainable params: 432725 (1.65 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 1/1 [==============================] - 3s 3s/step
